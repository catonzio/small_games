# %%
import networkx as nx

G = nx.DiGraph()

for i, state in enumerate(states):
    G.add_node(i, label=str(state))

for parent, children in tuples.items():
    for c in children:
        if c:
            G.add_edge(parent, c)

nx.draw(G, with_labels=True)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Generate parent-child relationships
parent_children = generate_tuples(states)

# Create a directed graph
G = nx.DiGraph()

# Add nodes
for node_index in parent_children.keys():
    G.add_node(node_index)

# Add edges
for parent, children in parent_children.items():
    for child in children:
        G.add_edge(parent, child)

# Draw the graph
pos = nx.spring_layout(G)
nx.draw(
    G,
    pos,
    with_labels=True,
    node_size=1000,
    node_color="skyblue",
    font_size=10,
    font_weight="bold",
)
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

T = nx.balanced_tree(2, 5)

pos = nx.nx_agraph.graphviz_layout(T, prog="twopi")
nx.draw(T, pos)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\danil\anaconda3\Lib\site-packages\networkx\drawing\nx_agraph.py:295, in pygraphviz_layout(G, prog, root, args)
#     294 try:
# --> 295     import pygraphviz
#     296 except ImportError as err:
#
# ModuleNotFoundError: No module named 'pygraphviz'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 6
#       2 import matplotlib.pyplot as plt
#       4 T = nx.balanced_tree(2, 5)
# ----> 6 pos = nx.nx_agraph.graphviz_layout(T, prog="twopi")
#       7 nx.draw(T, pos)
#       8 plt.show()
#
# File c:\Users\danil\anaconda3\Lib\site-packages\networkx\drawing\nx_agraph.py:251, in graphviz_layout(G, prog, root, args)
#     220 def graphviz_layout(G, prog="neato", root=None, args=""):
#     221     """Create node positions for G using Graphviz.
#     222
#     223     Parameters
#    (...)
#     249     see https://gitlab.com/graphviz/graphviz/-/issues/1767 for more info.
#     250     """
# --> 251     return pygraphviz_layout(G, prog=prog, root=root, args=args)
#
# File c:\Users\danil\anaconda3\Lib\site-packages\networkx\drawing\nx_agraph.py:297, in pygraphviz_layout(G, prog, root, args)
#     295     import pygraphviz
#     296 except ImportError as err:
# --> 297     raise ImportError(
#     298         "requires pygraphviz " "http://pygraphviz.github.io/"
#     299     ) from err
#     300 if root is not None:
#     301     args += f"-Groot={root}"
#
# ImportError: requires pygraphviz http://pygraphviz.github.io/
